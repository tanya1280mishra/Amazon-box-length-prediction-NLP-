# %%
# !pip install kaggle
# !pip install kagglehub

# %%
# import kagglehub
# # Download latest version
# path = kagglehub.dataset_download("sarthakkapaliya/amazon-product-length-prediction-dataset")

# print("Path to dataset files:", path)

# %% [markdown]
# I have used a LSTM model to predict the length od the box
# the model does not gives very good result but i will i am trying to improve its performance

# %%
import pandas as pd
import numpy as np

# %%
# sample_sub=pd.read_csv('/home/gesture-queen/VSCode/LSTMBoxPrediction/dataset/sample_submission.csv')
test_df=pd.read_csv('/home/gesture-queen/VSCode/LSTMBoxPrediction/dataset/test.csv')
train_df=pd.read_csv('/home/gesture-queen/VSCode/LSTMBoxPrediction/dataset/train.csv')

# %%
# print(test.sample(10))
print(len(test_df))
test_df.isnull().sum()
# Out:
# 734736
# PRODUCT_ID              0
# TITLE                   5
# BULLET_POINTS      275926
# DESCRIPTION        380001
# PRODUCT_TYPE_ID         0
# dtype: int64

# %%
# print(train.sample(10))
print(len(train_df)) 
train_df.isnull().sum()
# Out:
# 2249698
# PRODUCT_ID               0
# TITLE                   13
# BULLET_POINTS       837366
# DESCRIPTION        1157382
# PRODUCT_TYPE_ID          0
# PRODUCT_LENGTH           0
# dtype: int64

# %%
train_df=train_df.dropna()

# %%
x=train_df[['BULLET_POINTS','DESCRIPTION','PRODUCT_ID']]
y=train_df['PRODUCT_LENGTH']

# %%
print(x.head(10))
x.shape
# Out:
#                                         BULLET_POINTS  \
# 2   [Loud Dual Tone Trumpet Horn, Compatible With ...
# 3   [Made By 95%cotton and 5% Lycra which gives yo...
# 5   [Simple and elegant, great for displaying indo...
# 7   [HIGH QUALITY PVC MATERIAL: The kitchen alumin...
# 9   [100% Pure And Natural Essential Oil Or Fragra...
# 10  [Good quality and Suitable to use.,This Produc...
# 14  [Segovia bottle consists of stainless steel wh...
# 21  [❤【Compatible mode】:This mobile phone case is ...
# 25  [Completed Natural & Herbal.,Fragrances:- Rose...
# 27  [Gemstone: Amethyst: Amethyst is a well known ...
#
#                                           DESCRIPTION  PRODUCT_ID
# 2   Specifications: Color: Red, Material: Aluminiu...     2765088
# 3   AISHAH Women's Lycra Cotton Ankel Leggings. Br...     1594019
# 5   HINS Brings you the most Elegant Looking Pot w...     2152929
# 7   <p><strong>Aluminum Foil Stickers-good kitchen...     2026580
# 9   Transform your home, workplace or hotel room i...     2998633
# 10  3NH Glasses Goggles Anti Fog Antis Windproof A...     2857066
# 14  Segovia bottle consists of stainless steel whi...     2790448
# 21  <b>Welcome to our store. We aim to offer uniqu...     2964715
# 25  PACK OF 65 INCENSE CONES. Best Quality Low Smo...     2120903
# 27  <p>These Stylish Earring for Women and Girls a...     2273102
# (1038458, 3)

# %%
y.head(10)
y.shape
# Out:
# (1038458,)

# %% [markdown]
# # Removing
# ### 1.Punctuation Mark
# ### 2.Short foem of complete form
# ### 3.replacing'-',()
# ### 4.spelling check

# %%
x['BULLET_POINTS'][3]
# Out:
# '[Made By 95%cotton and 5% Lycra which gives you 4 ways stretchable comfort, GSM 180 to 190,Come with Elasticized Waist Band, Slim Fit,Bubble free fabric and High quality steaching, Bio Wash,Skin-friendly fabric,ANKLE LENGTH LEGGINGS PACK OF 2]'

# %%
# converting to lower case
x['DESCRIPTION'] = x['DESCRIPTION'].str.lower()
x['BULLET_POINTS'] = x['BULLET_POINTS'].str.lower()
# Out:
# /tmp/ipykernel_4679/3577375439.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['DESCRIPTION'] = x['DESCRIPTION'].str.lower()
# /tmp/ipykernel_4679/3577375439.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['BULLET_POINTS'] = x['BULLET_POINTS'].str.lower()

# %%
x=x[:458]
y=y[:458]
x.shape,y.shape
# Out:
# ((458, 3), (458,))

# %%
#REMOVING THE the html tags
import re
def remove_html_tags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'', text)

x['DESCRIPTION']=x['DESCRIPTION'].apply(remove_html_tags)
x['BULLET_POINTS']=x['BULLET_POINTS'].apply(remove_html_tags)

# %%
import re
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

x['BULLET_POINTS']=x['BULLET_POINTS'].apply(remove_emoji)
x['DESCRIPTION']=x['DESCRIPTION'].apply(remove_emoji)

# %%
x['DESCRIPTION'][7],x['BULLET_POINTS'][21]
# Out:
# ("aluminum foil stickers-good kitchen helper for mom and wife.&nbsp;specification: &nbsp;-materials: high-quality pvc &nbsp;-size: 2 mt&nbsp;-color: silver &nbsp;-friendly note: please buy enough rolls at a time to make sure that these wallpaper comes from the same batch to avoid color difference. &nbsp;-this aluminum foil stickers can be used for any dry, clean and smooth surface.&nbsp;features: &nbsp;1.high temperature resistant material is suitable for kitchen, which resists temperatures up to 250 celsius. it can be used for a long time and will not deform. &nbsp;2.easily to cut up: a grid line in square on the back, easy for you get the size you need when you cut.&nbsp;how to use? &nbsp;1.before sticking the kitchen oil proof wallpaper, please clean and dry surface with mild soap and water. make sure that surface is flat and without any carve. &nbsp;2.just cut out the size you want. &nbsp;3.use dishcloth or card to remove any air bubbles.&nbsp;package included: &nbsp;1 × kitchen backsplash wallpaper&nbsp;100% satisfaction guaranteed: &nbsp;we are always available to provide professional customer service before and after your purchase, so don't wait any longer and enjoy it right now.&nbsp;&nbsp;",
#  '[compatible mode:this mobile phone case is only compatible with iphone 13.it supports wireless charging. the precise cutout allows easy access to the charging port, buttons and camera.,screen & camera protection: made of high quality shockproof tpu material that protects against falls,drops ,scratches, bumps and more.the raised screen and camera edges help protect screen and camera from scratches.,clear vivid patterns : the clear and fashionable patterns make your mobile phone look very personalized. made with an unique printing technique, these patterns won’t rub off, fade or smudge.,perfect gifts& anti-yellow: fashionable and unique design and exquisite patterns are a good choice for gifts. high quality printing technology ensures that the pattern will not fade, turn yellow or fall off during use.,after-sale service:worry free after sales. if you have any questions, feel free to contact and we will reply within 24 hours.]')

# %%
# converting short to normal forms of english
def custom_normalize(text):
    replacements={"can't": "cannot",
                "won't": "will not",
                "aren't": "are not",
                "couldn't": "could not",
                "didn't": "did not",
                "doesn't": "does not",
                "don't": "do not",
                "hadn't": "had not",
                "hasn't": "has not",
                "haven't": "have not",
                "isn't": "is    not",
                "mustn't": "must not",
                "shouldn't": "should not",
                "wasn't": "was not",
                "weren't": "were not",
                # "wouldn't":    "would not",
                "I'm": "I am",
                "I've": "I have",
                "I'd": "I would",
                "I'll": "I will",
                "you're": "you are",
                "you've": "you have",
                "you'd": "you would",
                "you'll": "you will",
                "he's": "he is",
                "he's": "he has",
                "he'd": "he would",
                "he'll": "he will",
                "she's": "she is",
                "she's": "she has",
                "she'd": "she would",
                "she'll": "she will",
                "it's": "it is",
                "it's": "it has",
                "it'll": "it will",
                "we're": "we are",
                "we've": "we have",
                "we'd": "we would",
                "we'll": "we will",
                "they're": "they are",
                "they've": "they have",
                "they'd": "they would",
                "they'll": "they will",
                "that's": "that is",
                "that's": "that has",
                "there's": "there is",
                "there's": "there has",
                "there're": "there are",
                "where's": "where is",
                "what's": "what is",
                "what's": "what has",
                "let's": "let us",
                "won't": "will not",
                "can't": "cannot",
                "shan't": "shall not",
                "ain't": "am not/are not/is not/has not/have not/had not",
                "could've": "could have",
                 "might've": "might have",
                "must've": "must have",
                "should've": "should have",
                "would've": "would have",
                "could've": "could have",
                "might've": "might have",
                "must've": "must have",
                "should've": "should have",
                "would've": "would have",
                "I'ma": "I am going to",
                "gonna": "going to",
                "wanna": "want to",
                "gotta": "got to/have got to",
                "kinda": "kind of",
                "sorta": "sort of",
                "lotta": "lot of",
                "outta": "out of",
                "boutta": "about to",
                "y'all": "you all",
                "ain't": "am not/are not/is not/has not/have not/had not",
                "could've": "could have",
                "might've": "might have",
                "must've": "must have",
                "should've": "should have",
                "would've": "would have",
                "could've": "could have",
                "might've": "might have",
                "must've": "must have",
                "should've": "should have",
                "would've": "would have",
                "I'ma": "I am going to",
                "gonna": "going to",
                "wanna": "want to",
                "gotta": "got to/have got to",
                "kinda": "kind of",
                "sorta": "sort of",
                "lotta": "lot of",
                "outta": "out of",
                "boutta": "about to",
                "y'all": "you all",
                "ain't": "am not/are not/is not/has not/have not/had not",
                "could've": "could have",
                "might've": "might have",
                "must've": "must have",
                "should've": "should have",
                "would've": "would have",
                "could've": "could have",
                "might've": "might have",
                "must've": "must have",
                "should've": "should have",
                "would've": "would have",
                "I'ma": "I am going to",
                "gonna": "going to",
                "wanna": "want to",
                "gotta": "got to/have got to",
                "kinda": "kind of",
                "sorta": "sort of",
                "lotta": "lot of",
                "outta": "out of",
                "boutta": "about to",
                "y'all": "you all",
                "%":" percent "}
    for short_form,full_form in replacements.items():
        text=text.replace(short_form,full_form)
    return text

x['DESCRIPTION']=x['DESCRIPTION'].apply(lambda x: custom_normalize(x))
x['BULLET_POINTS']=x['BULLET_POINTS'].apply(lambda x: custom_normalize(x))

# %%
x['DESCRIPTION'][3],x['BULLET_POINTS'][3]
# Out:
# ("aishah women's lycra cotton ankel leggings. brand: alishah length: ankel length leggings. size chart medium: 28 - 30 inch large: 30 - 32 inch x-large: 32 - 34 inch 2x-large: 34 - 38 inch the color fade will not be there in washing. this cotton stretch leggings is designed to provide absolute comfort and body fit. pair it with short or long kurta for modern look. high on style, fit and finish, this leggings is sure to lend you a sophisticated look. please wash the dark colors separately in order to improve the product life. disclaimer: product color may slightly vary due to photographic lighting sources or your monitor settings. please order according to your waist size mentioned in size chart",
#  '[made by 95 percent cotton and 5 percent  lycra which gives you 4 ways stretchable comfort, gsm 180 to 190,come with elasticized waist band, slim fit,bubble free fabric and high quality steaching, bio wash,skin-friendly fabric,ankle length leggings pack of 2]')

# %%
# removing punctuation mark
import string
exclude=string.punctuation
import pandas as pd

def remove_punc_safe(text, exclude):
    if isinstance(text, str):
        for char in exclude:
            text = text.replace(char, '')
    return text

# Apply the function to your columns
x['DESCRIPTION'] = x['DESCRIPTION'].apply(lambda x: remove_punc_safe(x, exclude))
x['BULLET_POINTS'] = x['BULLET_POINTS'].apply(lambda x: remove_punc_safe(x, exclude))

# %%
def remove_url(text):
    pattern = re.compile(r'https?://\S+|www\.\S+')
    return pattern.sub(r'', text)

x['BULLET_POINTS']=x['BULLET_POINTS'].apply(remove_url)
x['DESCRIPTION']=x['DESCRIPTION'].apply(remove_url)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer=Tokenizer()
# Out:
# 2025-03-17 15:23:12.160131: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-17 15:23:12.263983: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742205192.311749    4679 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742205192.323854    4679 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1742205192.403892    4679 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742205192.403909    4679 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742205192.403912    4679 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742205192.403913    4679 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-03-17 15:23:12.414292: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
x['text']=x['BULLET_POINTS'] +" "+ x['DESCRIPTION']
x['text'][3]
# Out:
# 'made by 95 percent cotton and 5 percent  lycra which gives you 4 ways stretchable comfort gsm 180 to 190come with elasticized waist band slim fitbubble free fabric and high quality steaching bio washskinfriendly fabricankle length leggings pack of 2 aishah womens lycra cotton ankel leggings brand alishah length ankel length leggings size chart medium 28  30 inch large 30  32 inch xlarge 32  34 inch 2xlarge 34  38 inch the color fade will not be there in washing this cotton stretch leggings is designed to provide absolute comfort and body fit pair it with short or long kurta for modern look high on style fit and finish this leggings is sure to lend you a sophisticated look please wash the dark colors separately in order to improve the product life disclaimer product color may slightly vary due to photographic lighting sources or your monitor settings please order according to your waist size mentioned in size chart'

# %%
y.shape
# Out:
# (458,)

# %%
x = x['text']
x.shape
# Out:
# (458,)

# %%
all_texts = x.to_numpy()
all_texts
# Out:
# array(['loud dual tone trumpet horn compatible with sx4electric air horn with compressor compatible with sx4high quality high intensity horn sound compatible with sx4color red compatible with sx4professional installation required compatible with sx4 specifications color red material aluminium voltage 12v db 130 db around material aluminum pump head  steel pump body  abs shell and parts db output 130db voltage 12v sound type dual tone application 12v voltage vehicles with battery above 20a package included 1 x dual tone air horn compatible with sx4',
#        'made by 95 percent cotton and 5 percent  lycra which gives you 4 ways stretchable comfort gsm 180 to 190come with elasticized waist band slim fitbubble free fabric and high quality steaching bio washskinfriendly fabricankle length leggings pack of 2 aishah womens lycra cotton ankel leggings brand alishah length ankel length leggings size chart medium 28  30 inch large 30  32 inch xlarge 32  34 inch 2xlarge 34  38 inch the color fade will not be there in washing this cotton stretch leggings is designed to provide absolute comfort and body fit pair it with short or long kurta for modern look high on style fit and finish this leggings is sure to lend you a sophisticated look please wash the dark colors separately in order to improve the product life disclaimer product color may slightly vary due to photographic lighting sources or your monitor settings please order according to your waist size mentioned in size chart',
ers sweaters etcnbspbranded wool knitting provides satisfaction and quality of knitting experiencenbspthis variety of wool contains many colors like black violet blue white red green multinbsp etcnbspthis crochet wool is a gauge 3 wool it has not a chunky thick wool it has a very soft thread yarn comes in many colors can be hand washet and delicat machine wash at 40° cnbspsimilar types of wools are  vardhman rosemary wool vardhman microshine wool oswal wool thread yarn for knitting note  this is not a yarn thick chunky wool not a thick wool for knitting it has a needle crochet yarn acrylic avaliable in gm and kg',
#        'pink floyd the wall postersize  12 x 18 inchrolled and packed in a solid cardboard tube to with double protection sheet to prevent from any external damageready to be framed premium quality posterprinted with ecofriendly uv resistant inks for bright and rich colours which are easy to clean must be protected from sunlight extreme temperature dust and moisture to ensure long life this is a 12 x 18 inch size poster print printed on high quality matte finish poster paper no cheap paper used quality is guaranteed',
#        'the back is made of mesh stitching it looks sexy and charming it keeps air flowing and keeps you cool when you sportbackless rounded curved hem scoop neck loose fit allows for easy layering over any bra offers you the maximum comfortthis fabric dries quickly it is stretchable breathable super soft lightweight skin friendly and moisture wickingthe workout tank top perfect for workout yoga running gym athletic trainning exercise or just daily weareasy to care machine or hand wash coldbelow 30° iron on loe heat settings do not bleach fihapyli workout tank tops for women sleeveless yoga tops for women mesh back tops racerback muscle tank tops workout tops for women backless gym tops running tank tops activewear tops green m',
#        'multifunctional use can be used for other display functions through the signal transmission linestrict quality control and quality assurance high safety factor can be used with peace of mindsmall size easy to carry and store convenient to use and with good performancewith memory card slot to facilitate the expansion of the experiment provide a wealth of sample programs480x320 hd resolution only a few io can light up the display feature1 480x320 hd resolution only a few io can light up the display2 with memory card slot to facilitate the expansion of the experiment provide a wealth of sample programs3 multifunctional use can be used for other display functions through the signal transmission line4 small size easy to carry and store convenient to use and with good performance5 strict quality control and quality assurance high safety factor can be used with peace of mindspecitem type lcd screen modulesize approx 35 inchtype tftdriver chip ili9488resolution 480 x 320 pixelmodule interface 4wire spi interfaceeffective display area aa area 4896 x 7344mm  19 x 29innbspmodule pcb floor size approx5634 x 98mm  22 x 39innbspvcc power supply voltage 33v5vlogic io voltage 33v ttl package list1 x lcd screen module',
#        'completely breathable and 100 percent  ecofriendlythe breathable storage bags made with nonwon fabric that allows air to circulate inside ultimately keeping stored items fresh for longercan folding in a small size save more space if not in usedouble strong zippersthe comforts storage bag has double smooth zippers so can open from the end or middle which make the storage bags easy to open and closethe zippers works well even with the bag fullour zippers are much stronger and bigger than otherswe can promise that ours can be used more than 1000 times not like most cheap underbed bags where zipper break after only few useseasy to carryside double handles and front two handles make them easy to carry or grab and pull out from under the bedinstantly know what has insidethrough the transparent top you can find the clothes blankets comforts conveniently and quickly without opening the blankets storage bagsmultipurpose storage optionsthis underbed storage bag fits perfectly under your bed stacked on each other they are large enough that i fit 4 quilts 1 twin 2 fullqueen and a king plus some pillowcases in just one of themalso works great for storing blankets and off season clothesdimensions 3937x1968x590 inches under the bed storage containersunderbed storage bins organizer for blanket clothes tidy up your closet and shelfwith clear window2 sturdy zippers4 strong handles set of
#        'good quality and suitable to usethis product comes in a proper packagingin case of any query or issue feel free to reach out to uscontains pack of 1delivery within 35 weeks globalniche leather car key case cover for for d fiesta mk7 st focus 3 mk3 mk2 fusion ka ecosport galaxy escort key ring car accessories color name red',
# ...
#        'fast ignition tester hand‑held coil on plug fast ignition tester battery powered with stable and professional performance designed to easily and quickly determine whether the cop produces the proper spark for the plug it is the quickest way to test for nostart conditionsthe main function the mini cop ignition system quick tester works by receiving the signal from the secondary ignition coil and the test result is accurate and reliable once the signal is received the tester will determine whether the cop produces the correct amount of voltage and arc durationprofessional design according to spark color and flash over distance to determine the quality of the coil if the voltage is correct the tester will beep and the red led indicator will flash if the arc duration is correct the green led will also flashhigh quality ignition coil tester is made of highquality abs material for durability and high quality can intuitively convenient to understand the operation of the ignition coil works on all sparkignition engines from small 2stroke engines with magnetos to modern cars with computercontrolled coil on plug systems100 percent  assurance this ignition system coil tester is 100 percent  brand new and high quality we promises every customer a 100 percent  shopping satisfaction feel free to reach us if you have any questions about your purchase we are always at your service reply within 24 hours click to buy now feature1 hand‑held coil on plug fast ignition tester battery powered with stable and professional performance2 designed to easily and quickly determine whether the cop produces the proper spark for the plug3 it works by receiving the signal from the secondary ignition coil and the test result is accurate and reliable4 once the signal is received the tester will determine whether the cop produces the correct amount of voltage and arc duration5 if the voltage is correct the tester will beep and the red led indicator will flash if the arc duration is correct the green led will also flashspecificationitem type ignition coil tester material absbattery cr2032 button battery 120mah builtinhow to use1 correctly connect the connector and sensor head to the tester2 the induction head is aligned with the ignition coil to start working and the working status of the ignition coil is judged according to the result of lightingtest resultsred led lightconsistent steady flashing and beeping indicates the cop is producing the correct amount of voltageno response or an inconsistent response indicates the cop is not producing the correct amount of voltage this may be caused by one of the following1fouled spark plug or incorrect gaps2damagedcorroded wires or connectors3faulty coil or pcmgreen led lightconsistent and steady flashing indicates the duration of the arc is correctno response or an inconsistent response indicates the duration of the arc is not correct this may be caused by one of the following1shorted windings inside the coil2 resistance or bad connections in the3 primary  secondary connections4 faulty coilpackage list1 x ignition coil tester1 x adapter lever1 x sensornbsp1 x manualnbsp1 x storage bag',
#        ' made of heavy duty chromium plated aluminium perfectly mating deep teeth ensure a positive noslip grip spring return handle  these canvas pliers have a smooth grip with textured metal clamps perfect for hand stretching your own canvases length 20cm  2 wide jaws brustro has selected the comprehensive range of artists accessories to make up a range of essential items to ensure that our customers have all they need to get started brustro artists canvas stretching pliers are made of heavy duty chromium plated aluminium used to grasp canvas snugly in one motion for stretching these chrome plated drop forged aluminium pliers feature spring return handle and nonslip 2 wide jaws that mate perfectly these 20cm heavy duty canvas pliers have secure grip brustro is a registered trademark of creative hands art materials pvt ltd',
#        'maple neck with cshaped profileindian laurel fingerboardvintagestyle singlecoil telecaster pickups with threeway switchingtopload telecaster bridge21 medium jumbo frets adding value to your purchase austin bazaar bundles your instrument with necessary accessories everything you need to start playing immediately comes in one box save yourself the hassle and save some money while you are at it a gig bag is included so you can keep your instrument safely packed away when you are on the go an easytouse clipon tuner is included so you can keep your instrument in tune a strap is included so you can practice or better yet perform while standing up picks are included so you can start playing right out of the box an austin bazaar instructional dvd is included so you can pick up some tips while learning your new instrument squier affinity series guitars are the best value in electric guitar design the affinity series telecaster is a solid squier player features include two singlecoil pickups with threeway switching smoothplaying indian laurel fingerboard with 21 medium jumbo frets and sixsaddle topload bridgecolor competition orangebody alderbody finish polyurethanecontrol knobs knurled flattopfingerboard indian laurelhardware finish chromeneck finish satin urethanepickguard 3ply whiteposition inlays white dotsbody shape telecasterneck material mapleneck shape c shapescale length 255 648 mmfingerboard radius 95 241 mmnumber of frets 21fret size medium jumbostring nut synthetic bonenut width 16 406 mmtruss rod standardtruss rod wrench nabridge pickup vintagestyle singlecoil telemiddle pickup neck pickup vintagestyle singlecoil telecontrols master volume master tonepickup switching 3position blade position 1 bridge pickup position 2 bridge and neck pickups position 3 neck pickuppickup configuration ssbridge 6saddle topload teletuning machines standard diecaststrings fender usa 250l nps 009042 gaugesunique features',
#        'includes 3 prewashed 100 percent  terry cotton washclothspractical attached loop for easy dryinggenerous size perfect for kids of all agesmachine washable stays soft wash after wash gentle on babys skin yet durable our super soft colorful washcloths are the perfect addition to bath time fun each cloth has an attached loop so you can easily hang it to dry',
#        'flattens and smoothsreduces waist dimension by 1 to 3flexible metal boning for comfortthree closure rows for a perfect fitnatural shape with realistic fill and droop smooth and slim your midsection these waistshaping cinchers will reduce your waist dimension by 1” to 3” to emphasize your natural curves the rubberized exterior and flexible metal boning provide gentle compression that’s comfortable for allday wear'],
#       dtype=object)

# %%
# Fit the tokenizer on this list
tokenizer.fit_on_texts(all_texts)

# %%
print(len(tokenizer.word_index))
tokenizer.word_index
# Out:
# 11641
# {'and': 1,
#  'the': 2,
#  'to': 3,
#  'for': 4,
#  'of': 5,
#  'a': 6,
#  'with': 7,
#  'is': 8,
#  'your': 9,
#  'in': 10,
#  'you': 11,
#  'it': 12,
#  'are': 13,
#  'this': 14,
#  'or': 15,
#  'from': 16,
#  'on': 17,
#  'can': 18,
#  'be': 19,
#  'will': 20,
#  'quality': 21,
#  'made': 22,
#  'size': 23,
#  'not': 24,
#  'as': 25,
#  'that': 26,
#  'all': 27,
#  'design': 28,
#  'material': 29,
#  'easy': 30,
#  'our': 31,
#  'any': 32,
#  'case': 33,
#  'cover': 34,
#  'use': 35,
#  'has': 36,
#  'by': 37,
#  'percent': 38,
#  'x': 39,
#  'perfect': 40,
#  'which': 41,
#  'back': 42,
#  'high': 43,
#  'we': 44,
#  'product': 45,
#  'soft': 46,
#  'color': 47,
#  '1': 48,
#  'an': 49,
#  'these': 50,
#  'durable': 51,
#  'have': 52,
#  'phone': 53,
#  'fit': 54,
#  'style': 55,
#  'at': 56,
#  'make': 57,
#  'comfortable': 58,
#  'gift': 59,
#  'also': 60,
#  'home': 61,
#  'fabric': 62,
#  'wear': 63,
#  'please': 64,
#  'more': 65,
#  'water': 66,
#  'designed': 67,
#  'great': 68,
#  'used': 69,
#  'up': 70,
#  'no': 71,
#  'look': 72,
#  'car': 73,
#  '2': 74,
#  'long': 75,
#  'best': 76,
#  'keep': 77,
#  'hand': 78,
#  'provide': 79,
#  'protection': 80,
#  'set': 81,
#  'free': 82,
#  'features': 83,
#  'very': 84,
#  'cotton': 85,
#  'plastic': 86,
#  'do': 87,
#  'light': 88,
#  'women': 89,
#  'if': 90,
#  'leather': 91,
#  'one': 92,
#  'wash': 93,
#  'inch': 94,
#  'other': 95,
#  'suitable': 96,
#  '100': 97,
#  'its': 98,
#  'out': 99,
#  'us': 100,
#  'comfort': 101,
#  'when': 102,
#  'so': 103,
#  'inches': 104,
#  'only': 105,
#  'finish': 106,
#  'without': 107,
#  'clean': 108,
#  'dry': 109,
#  'room': 110,
#  'premium': 111,
#  'beautiful': 112,
#  'while': 113,
#  '3': 114,
#  'length': 115,
#  'new': 116,
#  'time': 117,
#  'contact': 118,
#  'skin': 119,
#  'they': 120,
#  'storage': 121,
#  'printed': 122,
#  'weight': 123,
#  'colors': 124,
#  'good': 125,
#  'different': 126,
#  'unique': 127,
#  'day': 128,
#  'products': 129,
#  'like': 130,
#  'device': 131,
#  'front': 132,
#  'screen': 133,
#  'note': 134,
#  'safe': 135,
#  'most': 136,
#  'makes': 137,
#  'mobile': 138,
#  'stylish': 139,
#  'may': 140,
#  'care': 141,
#  'table': 142,
#  'baby': 143,
#  'easily': 144,
#  'just': 145,
#  'wall': 146,
#  'each': 147,
#  'kitchen': 148,
#  'feel': 149,
#  'lightweight': 150,
#  'full': 151,
#  'there': 152,
#  'protect': 153,
#  'using': 154,
#  'covers': 155,
#  'solid': 156,
#  'type': 157,
#  'provides': 158,
#  'package': 159,
#  '4': 160,
#  'resistant': 161,
#  'about': 162,
#  'get': 163,
#  'top': 164,
#  'bag': 165,
#  'glass': 166,
#  'well': 167,
#  'pack': 168,
#  'give': 169,
#  'scratches': 170,
#  'them': 171,
#  'included': 172,
#  'space': 173,
#  'than': 174,
#  'side': 175,
#  'nbsp': 176,
#  'hair': 177,
#  'into': 178,
#  'party': 179,
#  'kids': 180,
#  'place': 181,
#  'designs': 182,
#  'comes': 183,
#  'frame': 184,
#  'before': 185,
#  'print': 186,
#  '12': 187,
#  'hard': 188,
#  'body': 189,
#  'brand': 190,
#  'living': 191,
#  'surface': 192,
#  'dust': 193,
#  'off': 194,
#  'cm': 195,
#  'ranger': 196,
#  'air': 197,
#  'elegant': 198,
#  'hot': 199,
#  'gifts': 200,
#  'polyester': 201,
#  'machine': 202,
#  'sleeve': 203,
#  'around': 204,
#  'gives': 205,
#  'prevent': 206,
#  'making': 207,
#  '5': 208,
#  'life': 209,
#  'both': 210,
#  'need': 211,
#  'fits': 212,
#  'small': 213,
#  'dress': 214,
#  'casual': 215,
#  'outdoor': 216,
#  'cases': 217,
#  'neck': 218,
#  'etc': 219,
#  'service': 220,
#  'access': 221,
#  'breathable': 222,
#  'shoes': 223,
#  'wallet': 224,
#  'stand': 225,
#  'within': 226,
#  'cold': 227,
#  'waist': 228,
#  'due': 229,
#  'items': 230,
#  'door': 231,
#  'work': 232,
#  'piece': 233,
#  'smooth': 234,
#  'after': 235,
#  'ideal': 236,
#  'men': 237,
#  'pocket': 238,
#  'metal': 239,
#  'samsung': 240,
#  'take': 241,
#  'convenient': 242,
#  'love': 243,
#  'help': 244,
#  'perfectly': 245,
#  'daily': 246,
#  'white': 247,
#  'extra': 248,
#  'carry': 249,
#  'strong': 250,
#  'office': 251,
#  'fashion': 252,
#  'wood': 253,
#  'every': 254,
#  'rubber': 255,
#  'decor': 256,
#  'item': 257,
#  'excellent': 258,
#  'height': 259,
#  'includes': 260,
#  'box': 261,
#  'support': 262,
#  '7': 263,
#  'sides': 264,
#  '8': 265,
#  'two': 266,
#  'allow': 267,
#  'printing': 268,
#  'store': 269,
#  'offer': 270,
#  'wedding': 271,
#  'family': 272,
#  'cool': 273,
#  'inside': 274,
#  'coffee': 275,
#  'compatible': 276,
#  'slim': 277,
#  'friendly': 278,
#  '–': 279,
#  'black': 280,
#  'matte': 281,
#  'dupatta': 282,
#  'shape': 283,
#  'womens': 284,
#  'pair': 285,
#  'simple': 286,
#  'card': 287,
#  'durability': 288,
#  'camera': 289,
#  'pattern': 290,
#  'install': 291,
#  'many': 292,
#  'laptop': 293,
#  'but': 294,
#  'been': 295,
#  'their': 296,
#  'over': 297,
#  'bags': 298,
#  'mesh': 299,
#  'quick': 300,
#  'handle': 301,
#  'put': 302,
#  'wide': 303,
#  'cute': 304,
#  'seat': 305,
#  'sure': 306,
#  'art': 307,
#  'charging': 308,
#  'technology': 309,
#  'cloth': 310,
#  'range': 311,
#  'hands': 312,
#  'warranty': 313,
#  'steel': 314,
#  'available': 315,
#  'special': 316,
#  'buttons': 317,
#  'width': 318,
#  'india': 319,
#  'colour': 320,
#  'accessories': 321,
#  'button': 322,
#  'mat': 323,
#  'efi': 324,
#  '30': 325,
#  'better': 326,
#  'add': 327,
#  'bottle': 328,
#  'experience': 329,
#  'protects': 330,
#  'cushion': 331,
#  'such': 332,
#  'ensure': 333,
#  'some': 334,
#  'adjustable': 335,
#  'feet': 336,
#  'installation': 337,
#  'chart': 338,
#  'order': 339,
#  'standard': 340,
#  'natural': 341,
#  'sturdy': 342,
#  'hanging': 343,
#  'multiple': 344,
#  'thick': 345,
#  'keeps': 346,
#  'maximum': 347,
#  'dirt': 348,
#  'allows': 349,
#  'attractive': 350,
#  'choose': 351,
#  'travel': 352,
#  'feature': 353,
#  'zipper': 354,
#  'model': 355,
#  'complete': 356,
#  'classic': 357,
#  'grip': 358,
#  'washable': 359,
#  'appearance': 360,
#  'lasting': 361,
#  'modern': 362,
#  'oil': 363,
#  'soap': 364,
#  'right': 365,
#  'occasion': 366,
#  '24': 367,
#  'elastic': 368,
#  'between': 369,
#  'sleeves': 370,
#  'keeping': 371,
#  'way': 372,
#  'face': 373,
#  'sizes': 374,
#  'instructions': 375,
#  'friends': 376,
#  'bottom': 377,
#  'cable': 378,
#  'flexible': 379,
#  '4x4': 380,
#  'aluminum': 381,
#  'head': 382,
#  'large': 383,
#  'against': 384,
#  'flat': 385,
#  'heat': 386,
#  'tea': 387,
#  'food': 388,
#  'tpu': 389,
#  'collection': 390,
#  'days': 391,
#  '20': 392,
#  'power': 393,
#  'pockets': 394,
#  'overall': 395,
#  'now': 396,
#  'fast': 397,
#  'red': 398,
#  'remove': 399,
#  'customer': 400,
#  'clear': 401,
#  'ports': 402,
#  'bed': 403,
#  'damage': 404,
#  'control': 405,
#  'even': 406,
#  'go': 407,
#  'come': 408,
#  'resistance': 409,
#  'wooden': 410,
#  'usb': 411,
#  'slightly': 412,
#  'enough': 413,
#  'want': 414,
#  'enjoy': 415,
#  'hours': 416,
#  'birthday': 417,
#  'touch': 418,
#  'helps': 419,
#  'house': 420,
#  'dimensions': 421,
#  'safety': 422,
#  'per': 423,
#  'green': 424,
#  'offers': 425,
#  'bedroom': 426,
#  'never': 427,
#  'does': 428,
#  'round': 429,
#  'jewelry': 430,
#  'dining': 431,
#  'slippers': 432,
#  'iron': 433,
#  'cleaning': 434,
#  'everyday': 435,
#  '10': 436,
#  'iphone': 437,
#  'edges': 438,
#  'ensures': 439,
#  '18': 440,
#  'open': 441,
#  'evening': 442,
#  'highly': 443,
#  'yarn': 444,
#  'wool': 445,
#  'through': 446,
#  'edge': 447,
#  'years': 448,
#  'designer': 449,
#  'shoulder': 450,
#  'collar': 451,
#  'canvas': 452,
#  'measurement': 453,
#  'much': 454,
#  'away': 455,
#  'regular': 456,
#  'decoration': 457,
#  'formal': 458,
#  'closure': 459,
#  'trendy': 460,
#  'acrylic': 461,
#  'mouse': 462,
#  '6': 463,
#  'fun': 464,
#  'flower': 465,
#  'choice': 466,
#  'materials': 467,
#  'cutouts': 468,
#  'girls': 469,
#  'fine': 470,
#  'loved': 471,
#  'ones': 472,
#  'sports': 473,
#  'occasions': 474,
#  'blue': 475,
#  'check': 476,
#  'crafted': 477,
#  'what': 478,
#  'shelf': 479,
#  'latest': 480,
#  'footwear': 481,
#  'sole': 482,
#  'protector': 483,
#  'furniture': 484,
#  'usa': 485,
#  'warm': 486,
#  'shorts': 487,
#  'shell': 488,
#  'battery': 489,
#  'highquality': 490,
#  'scratch': 491,
#  'm': 492,
#  'handmade': 493,
#  'spring': 494,
#  'dresses': 495,
#  'area': 496,
#  'original': 497,
#  'looks': 498,
#  'super': 499,
#  'little': 500,
#  'construction': 501,
#  'performance': 502,
#  'galaxy': 503,
#  'macbook': 504,
#  'waterproof': 505,
#  'bar': 506,
#  'cup': 507,
#  'strap': 508,
#  'sun': 509,
#  'guard': 510,
#  'various': 511,
#  'abs': 512,
#  'fade': 513,
#  'temperature': 514,
#  'buy': 515,
#  'create': 516,
#  '35': 517,
#  'stainless': 518,
#  'first': 519,
#  'w': 520,
#  'floor': 521,
#  'shoe': 522,
#  'single': 523,
#  'portable': 524,
#  'secure': 525,
#  'lens': 526,
#  'last': 527,
#  'capacity': 528,
#  'holder': 529,
#  'during': 530,
#  'picture': 531,
#  'upper': 532,
#  'contains': 533,
#  'pillow': 534,
#  'double': 535,
#  'desk': 536,
#  'lace': 537,
#  'match': 538,
#  'inner': 539,
#  'slip': 540,
#  'manual': 541,
#  'looking': 542,
#  'moisture': 543,
#  'professional': 544,
#  'bumps': 545,
#  'low': 546,
#  'ring': 547,
#  'vehicle': 548,
#  'satin': 549,
#  'tables': 550,
#  'packed': 551,
#  'down': 552,
#  'makeup': 553,
#  'bathroom': 554,
#  'watch': 555,
#  'guarantee': 556,
#  'system': 557,
#  'belt': 558,
#  'part': 559,
#  'pu': 560,
#  'vibrant': 561,
#  'blend': 562,
#  'helmet': 563,
#  'shock': 564,
#  'dog': 565,
#  'rug': 566,
#  'medium': 567,
#  'short': 568,
#  'vary': 569,
#  'real': 570,
#  'cut': 571,
#  'layer': 572,
#  'function': 573,
#  'questions': 574,
#  'including': 575,
#  'variety': 576,
#  'l': 577,
#  'book': 578,
#  'adds': 579,
#  'mm': 580,
#  'clothes': 581,
#  'fresh': 582,
#  'plate': 583,
#  'flip': 584,
#  'extremely': 585,
#  'number': 586,
#  'problems': 587,
#  'driving': 588,
#  'mens': 589,
#  'luxury': 590,
#  'problem': 591,
#  'led': 592,
#  'imported': 593,
#  'pro': 594,
#  'sound': 595,
#  'stretch': 596,
#  'powder': 597,
#  'same': 598,
#  'proof': 599,
#  'avoid': 600,
#  'difference': 601,
#  'purchase': 602,
#  'proper': 603,
#  'along': 604,
#  'chest': 605,
#  'approx': 606,
#  'traditional': 607,
#  'smart': 608,
#  'under': 609,
#  'pouch': 610,
#  'world': 611,
#  'polycarbonate': 612,
#  'providing': 613,
#  'bleach': 614,
#  'display': 615,
#  'end': 616,
#  'i': 617,
#  'details': 618,
#  'reduce': 619,
#  'hold': 620,
#  'sublimation': 621,
#  'diameter': 622,
#  'heavy': 623,
#  'image': 624,
#  'superior': 625,
#  'being': 626,
#  'shapes': 627,
#  'pieces': 628,
#  'dual': 629,
#  'specifications': 630,
#  'indoor': 631,
#  'pvc': 632,
#  'always': 633,
#  'essential': 634,
#  'beauty': 635,
#  'who': 636,
#  'sticks': 637,
#  'anywhere': 638,
#  'query': 639,
#  'fashionable': 640,
#  'drops': 641,
#  'jewellery': 642,
#  'amazon': 643,
#  'christmas': 644,
#  'custom': 645,
#  'liquid': 646,
#  'rich': 647,
#  'running': 648,
#  'save': 649,
#  'transparent': 650,
#  'because': 651,
#  'tablet': 652,
#  'magnetic': 653,
#  'lock': 654,
#  '500': 655,
#  'content': 656,
#  'crystal': 657,
#  'activities': 658,
#  'accessory': 659,
#  'bangles': 660,
#  'panel': 661,
#  'people': 662,
#  'meet': 663,
#  'tv': 664,
#  'plush': 665,
#  'pad': 666,
#  'indian': 667,
#  'cards': 668,
#  'bust': 669,
#  'normal': 670,
#  'pure': 671,
#  'base': 672,
#  'amp': 673,
#  'description': 674,
#  'less': 675,
#  'night': 676,
#  'name': 677,
#  'shirt': 678,
#  'recommended': 679,
#  'foot': 680,
#  '15': 681,
#  'would': 682,
#  'play': 683,
#  'devices': 684,
#  'synthetic': 685,
#  'walking': 686,
#  'mirror': 687,
#  'music': 688,
#  'year': 689,
#  'spandex': 690,
#  'glossy': 691,
#  'form': 692,
#  'too': 693,
#  'board': 694,
#  'prints': 695,
#  'children': 696,
#  'diaper': 697,
#  'organic': 698,
#  'stay': 699,
#  'arm': 700,
#  '700': 701,
#  'washing': 702,
#  'dark': 703,
#  'monitor': 704,
#  'garden': 705,
#  'silver': 706,
#  'texture': 707,
#  'those': 708,
#  'reach': 709,
#  'gym': 710,
#  'precise': 711,
#  'patterns': 712,
#  '13': 713,
#  'prevents': 714,
#  'pink': 715,
#  'maxi': 716,
#  'beach': 717,
#  'summer': 718,
#  'thread': 719,
#  'nylon': 720,
#  'knitting': 721,
#  'workout': 722,
#  'beautifully': 723,
#  'holiday': 724,
#  'start': 725,
#  'thickness': 726,
#  'needs': 727,
#  'gentle': 728,
#  'key': 729,
#  'charger': 730,
#  'total': 731,
#  'curtain': 732,
#  'contemporary': 733,
#  'customers': 734,
#  'business': 735,
#  'film': 736,
#  'puzzle': 737,
#  'impossible': 738,
#  'brass': 739,
#  'lighting': 740,
#  'center': 741,
#  'removable': 742,
#  'foil': 743,
#  'satisfaction': 744,
#  'could': 745,
#  'incense': 746,
#  'types': 747,
#  'grade': 748,
#  'phones': 749,
#  'show': 750,
#  'charcoal': 751,
#  'bring': 752,
#  'window': 753,
#  '16': 754,
#  'find': 755,
#  'online': 756,
#  'fitting': 757,
#  'precision': 758,
#  'blankets': 759,
#  'tops': 760,
#  'times': 761,
#  'blanket': 762,
#  'leaves': 763,
#  'net': 764,
#  'value': 765,
#  'pads': 766,
#  'fully': 767,
#  'shopping': 768,
#  'shirts': 769,
#  'silicone': 770,
#  'addition': 771,
#  'impact': 772,
#  'luxurious': 773,
#  'process': 774,
#  'pick': 775,
#  '3d': 776,
#  'direct': 777,
#  'tool': 778,
#  'computer': 779,
#  'include': 780,
#  'wet': 781,
#  'flowers': 782,
#  'mug': 783,
#  'microfiber': 784,
#  'vintage': 785,
#  'tough': 786,
#  'built': 787,
#  'toy': 788,
#  '5g': 789,
#  'charge': 790,
#  'pain': 791,
#  'filler': 792,
#  'wiper': 793,
#  'ecofriendly': 794,
#  'stick': 795,
#  'welcome': 796,
#  'four': 797,
#  'handcrafted': 798,
#  'refer': 799,
#  'circumference': 800,
#  'fiber': 801,
#  'combination': 802,
#  'movement': 803,
#  '60': 804,
#  'foam': 805,
#  'added': 806,
#  'ease': 807,
#  'working': 808,
#  'freely': 809,
#  'own': 810,
#  '50': 811,
#  'manufactured': 812,
#  'colorful': 813,
#  'paper': 814,
#  'organizer': 815,
#  'cannot': 816,
#  'simply': 817,
#  'elegance': 818,
#  'styles': 819,
#  'price': 820,
#  'outside': 821,
#  'press': 822,
#  'universal': 823,
#  'smartphone': 824,
#  'speaker': 825,
#  'ready': 826,
#  'strength': 827,
#  'money': 828,
#  '11': 829,
#  'happy': 830,
#  'manufacturer': 831,
#  'uses': 832,
#  'nontoxic': 833,
#  'then': 834,
#  'ultra': 835,
#  'yet': 836,
#  'accurate': 837,
#  'let': 838,
#  'nice': 839,
#  'rooms': 840,
#  'manufacturing': 841,
#  'serving': 842,
#  'tempered': 843,
#  'mini': 844,
#  'drive': 845,
#  'weather': 846,
#  'class': 847,
#  'barrier': 848,
#  'animal': 849,
#  '।': 850,
#  'correct': 851,
#  'eu': 852,
#  'duvet': 853,
#  'coil': 854,
#  'settings': 855,
#  'according': 856,
#  'pot': 857,
#  'stains': 858,
#  'shelves': 859,
#  'line': 860,
#  'adding': 861,
#  'turn': 862,
#  'ink': 863,
#  'especially': 864,
#  's': 865,
#  'skirt': 866,
#  'carpet': 867,
#  'skirts': 868,
#  'wearing': 869,
#  'parties': 870,
#  'multi': 871,
#  'loose': 872,
#  'quickly': 873,
#  'functions': 874,
#  'versatile': 875,
#  'fruit': 876,
#  'rest': 877,
#  'slight': 878,
#  'position': 879,
#  'ceramic': 880,
#  'nonslip': 881,
#  'books': 882,
#  'mind': 883,
#  'hence': 884,
#  'healthy': 885,
#  'holes': 886,
#  'decorate': 887,
#  'sofa': 888,
#  'hang': 889,
#  'dancing': 890,
#  'harmful': 891,
#  'compartment': 892,
#  'yourself': 893,
#  'solution': 894,
#  'lip': 895,
#  'market': 896,
#  'jack': 897,
#  'big': 898,
#  'rack': 899,
#  'sleep': 900,
#  'feeling': 901,
#  'cups': 902,
#  'maintain': 903,
#  'genuine': 904,
#  'rod': 905,
#  'actual': 906,
#  'important': 907,
#  'measurements': 908,
#  'kindly': 909,
#  'stitch': 910,
#  'buckle': 911,
#  'toys': 912,
#  'clip': 913,
#  'v': 914,
#  'boy': 915,
#  'muslin': 916,
#  'dimension': 917,
#  'cactus': 918,
#  '800': 919,
#  'ignition': 920,
#  'voltage': 921,
#  'above': 922,
#  '95': 923,
#  'gsm': 924,
#  'brings': 925,
#  'switch': 926,
#  'monitors': 927,
#  'sheet': 928,
#  'dishwasher': 929,
#  'square': 930,
#  'mild': 931,
#  'diy': 932,
#  'issue': 933,
#  'hiking': 934,
#  'raised': 935,
#  'should': 936,
#  'anniversary': 937,
#  'xl': 938,
#  'decorative': 939,
#  'main': 940,
#  'needed': 941,
#  'cars': 942,
#  'plus': 943,
#  'suit': 944,
#  'email': 945,
#  'detail': 946,
#  'fabrics': 947,
#  'interior': 948,
#  'delicate': 949,
#  'gold': 950,
#  'socks': 951,
#  'tube': 952,
#  'uv': 953,
#  'must': 954,
#  'poster': 955,
#  'bra': 956,
#  'few': 957,
#  'favorite': 958,
#  'reliable': 959,
#  'giving': 960,
#  'straight': 961,
#  'keyboard': 962,
#  'slide': 963,
#  'finger': 964,
#  'having': 965,
#  'drawstring': 966,
#  'floral': 967,
#  'hook': 968,
#  'seller': 969,
#  'satisfied': 970,
#  'plug': 971,
#  'lifetime': 972,
#  'absorb': 973,
#  'snap': 974,
#  'wonderful': 975,
#  'straps': 976,
#  'thin': 977,
#  'longlasting': 978,
#  'clothing': 979,
#  'mats': 980,
#  'possible': 981,
#  'reading': 982,
#  'move': 983,
#  'vase': 984,
#  'boys': 985,
#  'zinc': 986,
#  'drill': 987,
#  'slots': 988,
#  'protecting': 989,
#  'lining': 990,
#  'ever': 991,
#  'pet': 992,
#  'juice': 993,
#  'outsole': 994,
#  'owl': 995,
#  'license': 996,
#  'vacuum': 997,
#  'compression': 998,
#  'mask': 999,
#  'cosmetic': 1000,
#  ...}

# %%
tokenized_sentence=[]
for sentence in all_texts:
  tokenized_sentence.append(tokenizer.texts_to_sequences([sentence])[0])

# %%
len(tokenized_sentence[20])
# Out:
# 60

# %%
len(all_texts)
# Out:
# 458

# %%
#as the supervised learning algos expect the same size of input so we will do zero_padding
max_length=max([len(x) for x in tokenized_sentence])  #max length for padding
max_length
# Out:
# 576

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences=pad_sequences(tokenized_sentence,maxlen=max_length,padding='pre')

# %%
padded_input_sequences.shape,y.shape
# Out:
# ((458, 576), (458,))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(padded_input_sequences, y, test_size=0.2, random_state=42)

# %%
#creating the LSTM Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,LSTM,Dense
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.layers import Reshape
from sklearn.metrics import r2_score

# %%
model=Sequential()
model.add(Embedding(88636,200,input_length=507))
model.add(LSTM(256,return_sequences=True))
model.add(LSTM(256))
model.add(Dense(1,activation='linear'))
# Out:
# /home/gesture-queen/VSCode/LSTMenv/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# W0000 00:00:1742205194.787456    4679 gpu_device.cc:2341] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mae', RootMeanSquaredError()])

# %%
model.build((None,507))  
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 507, 200)       │    17,727,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 507, 256)       │       467,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 256)            │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,720,737 (71.41 MB)
#  Trainable params: 18,720,737 (71.41 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history=model.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 13s 897ms/step - loss: 8001790.5000 - mae: 1229.2235 - root_mean_squared_error: 2750.9263
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 883ms/step - loss: 6953577.5000 - mae: 1250.8164 - root_mean_squared_error: 2591.7070
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 903ms/step - loss: 4754470.0000 - mae: 1100.8143 - root_mean_squared_error: 2120.6409
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 895ms/step - loss: 9656185.0000 - mae: 1336.6285 - root_mean_squared_error: 3064.2935
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 918ms/step - loss: 5635616.5000 - mae: 1280.5913 - root_mean_squared_error: 2367.8611
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 891ms/step - loss: 5395389.0000 - mae: 1182.2667 - root_mean_squared_error: 2292.4275
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 957ms/step - loss: 5183492.5000 - mae: 1172.2734 - root_mean_squared_error: 2214.8567
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 899ms/step - loss: 8983768.0000 - mae: 1295.4824 - root_mean_squared_error: 2935.2263
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 942ms/step - loss: 5653371.0000 - mae: 1230.7812 - root_mean_squared_error: 2362.3176
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 1000ms/step - loss: 4637366.0000 - mae: 1129.0399 - root_mean_squared_error: 2122.3193
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 944ms/step - loss: 8953989.0000 - mae: 1364.5240 - root_mean_squared_error: 2932.7373
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 894ms/step - loss: 6562319.0000 - mae: 1233.9962 - root_mean_squared_error: 2549.6191
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 904ms/step - loss: 8186530.0000 - mae: 1338.6278 - root_mean_squared_error: 2836.5657
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 861ms/step - loss: 6950197.5000 - mae: 1102.8757 - root_mean_squared_error: 2594.1372
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 861ms/step - loss: 7437911.0000 - mae: 1083.9712 - root_mean_squared_error: 2653.6396
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 899ms/step - loss: 4617715.0000 - mae: 973.3926 - root_mean_squared_error: 2094.0161
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 890ms/step - loss: 4453056.0000 - mae: 971.8445 - root_mean_squared_error: 2078.7983
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 925ms/step - loss: 5040301.0000 - mae: 1017.7860 - root_mean_squared_error: 2227.7319
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 930ms/step - loss: 5074121.5000 - mae: 1043.6016 - root_mean_squared_error: 2225.2048
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 894ms/step - loss: 7950876.5000 - mae: 1117.9918 - root_mean_squared_error: 2796.0225
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 892ms/step - loss: 7916367.0000 - mae: 1183.7347 - root_mean_squared_error: 2799.3020
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 886ms/step - loss: 3908046.5000 - mae: 896.0887 - root_mean_squared_error: 1919.1608
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 891ms/step - loss: 4430246.0000 - mae: 912.6276 - root_mean_squared_error: 2042.0914
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 897ms/step - loss: 5338995.5000 - mae: 985.5701 - root_mean_squared_error: 2295.3135
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 921ms/step - loss: 5498630.0000 - mae: 1021.2854 - root_mean_squared_error: 2318.6738
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 915ms/step - loss: 6121345.5000 - mae: 1002.7598 - root_mean_squared_error: 2433.6392
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 896ms/step - loss: 5072501.5000 - mae: 965.6396 - root_mean_squared_error: 2210.8289
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 891ms/step - loss: 4642226.0000 - mae: 976.0564 - root_mean_squared_error: 2077.8406
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 897ms/step - loss: 5451003.5000 - mae: 1033.4163 - root_mean_squared_error: 2305.5457
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 898ms/step - loss: 4106709.5000 - mae: 897.9116 - root_mean_squared_error: 1993.6993
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 885ms/step - loss: 3817338.2500 - mae: 867.9081 - root_mean_squared_error: 1865.2637
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 893ms/step - loss: 4001651.7500 - mae: 873.0569 - root_mean_squared_error: 1905.0967
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 887ms/step - loss: 8143005.0000 - mae: 1157.0234 - root_mean_squared_error: 2797.9993
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 878ms/step - loss: 7113282.0000 - mae: 1051.8643 - root_mean_squared_error: 2647.7905
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 894ms/step - loss: 5419275.0000 - mae: 983.7180 - root_mean_squared_error: 2279.5613
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 901ms/step - loss: 5502534.5000 - mae: 1009.2329 - root_mean_squared_error: 2294.9849
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 896ms/step - loss: 6276627.0000 - mae: 1050.7662 - root_mean_squared_error: 2449.2041

# %%
#VALIDATION 
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.metrics import RootMeanSquaredError
import matplotlib.pyplot as plt

y_pred=model.predict(X_test)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
mae=mean_squared_error(y_test,y_pred)

print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")

# Visualize predictions vs actual values
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r--')
plt.xlabel('Actual Box Length')
plt.ylabel('Predicted Box Length')
plt.title('Actual vs Predicted Box Length')
plt.tight_layout()
plt.show()

# Error distribution
errors = y_pred.flatten() - y_test
plt.figure(figsize=(10, 6))
plt.hist(errors, bins=30)
plt.xlabel('Prediction Error')
plt.ylabel('Count')
plt.title('Distribution of Prediction Errors')
plt.tight_layout()
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 343ms/step
# Mean Squared Error (MSE): 6901454.4516
# Root Mean Squared Error (RMSE): 2627.0619
# Mean Absolute Error (MAE): 6901454.4516

# %%
test_df
# Out:
#         PRODUCT_ID                                              TITLE  \
# 1          1729783  DCGARING Microfiber Throw Blanket Warm Fuzzy P...
# 2          1871949  I-Match Auto Parts Front License Plate Bracket...
# 3          1107571  PinMart Gold Plated Excellence in Service 1 Ye...
# 5          2782548  Evershine Shoppee 10m Waxed Nylon Thread Cotto...
# 11         2736605  SHASAK Sanganer Hand Block Printed Short Kurta...
# ...            ...                                                ...
# 734728     1805278  E RELAX Arm Blaster-Heavy Duty Padded Thick Ga...
# 734731      921419  Casual Canine Basic Hoodie for Dogs, 16" Mediu...
# 734733      841529  Axor 39135001 Citterio Widespread Faucet with ...
# 734734     1190194  Caroline's Treasures BB1801DS812 Halloween Bas...
# 734735     1040810  Amsahr 18C1623 Lexmark X3530 Remanufactured Re...
#
#                                             BULLET_POINTS  \
# 1       [QUALITY GUARANTEED: Luxury cozy plush polyest...
# 2       [Front License Plate Bracket Made Of Plastic,D...
# 3       [Available as a single item or bulk packed. Se...
# 5       [Kindly Refer The Product Description Before B...
# 11      [Confused between wearing a T-shirt and a shir...
# ...                                                   ...
# 734728  [We offer you quality material, durable straps...
# 734731  [Brightly colored pet sweatshirts with authent...
# 734733  [8-Inch centers,1/2-Inch IPS inlets,9-Inch spo...
# 734734  [Indoor or outdoor aluminum artwork prints,8 i...
# 734735  [Engineered and Manufactured Under European St...
#
#                                               DESCRIPTION  PRODUCT_TYPE_ID
# 1       <b>DCGARING Throw Blanket</b><br><br> <b>Size ...             1622
# 2       Replacement for The Following Vehicles:2020 LE...             7540
# 3       Our Excellence in Service Lapel Pins feature a...            12442
# 5       Description: Material: Nylon Length: about 10m...            11205
# 11      Men’s Pure Cotton Sanganeri Hand-Block Print S...             2911
# ...                                                   ...              ...
# 734728  E RELAX arm blaster is made from superior grad...            12955
# 734731  ZA6015 16 43 Size-See Chart Below: Medium: 16"...             7073
# 734733  39135001 Features: -ADA compliant. -Includes p...            10645
# 734734  Features. Great for inside or outside these Al...            12680
# 734735  Our Remanufactured Replacement Lexmark Ink Car...                0
#
# [336998 rows x 5 columns]

# %%
#preprocessing the test daat
test_df=test_df.dropna()

x_test=test_df[['BULLET_POINTS','DESCRIPTION']]

# converting to lower case
x_test['DESCRIPTION'] = x_test['DESCRIPTION'].str.lower()
x_test['BULLET_POINTS'] = x_test['BULLET_POINTS'].str.lower()
x_test=x_test[:458]
x_test.shape

#REMOVING THE the html tags
x_test['DESCRIPTION']=x_test['DESCRIPTION'].apply(remove_html_tags)
x_test['BULLET_POINTS']=x_test['BULLET_POINTS'].apply(remove_html_tags)

x_test['BULLET_POINTS']=x_test['BULLET_POINTS'].apply(remove_emoji)
x_test['DESCRIPTION']=x_test['DESCRIPTION'].apply(remove_emoji)


# converting short to normal forms of english
x_test['DESCRIPTION']=x_test['DESCRIPTION'].apply(lambda x: custom_normalize(x))
x_test['BULLET_POINTS']=x_test['BULLET_POINTS'].apply(lambda x: custom_normalize(x))

# Apply the function to your columns
x_test['DESCRIPTION'] = x_test['DESCRIPTION'].apply(lambda x: remove_punc_safe(x, exclude))
x_test['BULLET_POINTS'] = x_test['BULLET_POINTS'].apply(lambda x: remove_punc_safe(x, exclude))

x_test['BULLET_POINTS']=x_test['BULLET_POINTS'].apply(remove_url)
x_test['DESCRIPTION']=x_test['DESCRIPTION'].apply(remove_url)

x_test['text']=x_test['BULLET_POINTS'] +" "+ x_test['DESCRIPTION']
x_test['text'][3]

x_test= x_test['text']
x_test.shape

all_texts_test = x_test.to_numpy()
all_texts_test

# Fit the tokenizer on this list
tokenizer.fit_on_texts(all_texts_test)

print(len(tokenizer.word_index))
tokenizer.word_index


tokenized_sentence_test=[]
for sentence in all_texts_test:
  tokenized_sentence_test.append(tokenizer.texts_to_sequences([sentence])[0])
  
  #as the supervised learning algos expect the same size of input so we will do zero_padding
max_length_test=max([len(x) for x in tokenized_sentence_test])  #max length for padding
max_length_test

padded_input_sequences_test=pad_sequences(tokenized_sentence_test,maxlen=max_length_test,padding='pre')
# Out:
# /tmp/ipykernel_4679/43973821.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test['DESCRIPTION'] = x_test['DESCRIPTION'].str.lower()
# 18662
# /tmp/ipykernel_4679/43973821.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test['BULLET_POINTS'] = x_test['BULLET_POINTS'].str.lower()

# %%
# Get predictions
predictions = model.predict(padded_input_sequences_test)
# 
# Convert predictions to appropriate format if needed (e.g., flatten if they're in a nested array)
predictions = predictions.flatten()

# Display some sample predictions
print("Sample predictions:")
for i in range(min(10, len(predictions))):
    print(f"Sample {i}: Predicted box length = {predictions[i]:.2f}")

# Basic statistics of predictions
print("\nPrediction Statistics:")
print(f"Mean predicted box length: {np.mean(predictions):.2f}")
print(f"Median predicted box length: {np.median(predictions):.2f}")
print(f"Min predicted box length: {np.min(predictions):.2f}")
print(f"Max predicted box length: {np.max(predictions):.2f}")
print(f"Standard deviation: {np.std(predictions):.2f}")

# Visualize prediction distribution
plt.figure(figsize=(10, 6))
plt.hist(predictions, bins=30)
plt.xlabel('Predicted Box Length')
plt.ylabel('Frequency')
plt.title('Distribution of Predicted Box Lengths')
plt.axvline(np.mean(predictions), color='r', linestyle='dashed', linewidth=1, label=f'Mean: {np.mean(predictions):.2f}')
plt.axvline(np.median(predictions), color='g', linestyle='dashed', linewidth=1, label=f'Median: {np.median(predictions):.2f}')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 372ms/step
# Sample predictions:
# Sample 0: Predicted box length = 283.73
# Sample 1: Predicted box length = 283.73
# Sample 2: Predicted box length = 283.73
# Sample 3: Predicted box length = 283.73
# Sample 4: Predicted box length = 283.73
# Sample 5: Predicted box length = 283.73
# Sample 6: Predicted box length = 283.73
# Sample 7: Predicted box length = 283.73
# Sample 8: Predicted box length = 283.73
# Sample 9: Predicted box length = 283.73
#
# Prediction Statistics:
# Mean predicted box length: 283.73
# Median predicted box length: 283.73
# Min predicted box length: 283.73
# Max predicted box length: 283.73
# Standard deviation: 0.00
